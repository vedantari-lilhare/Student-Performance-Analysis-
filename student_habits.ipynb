# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

student_habits = pd.read_csv(r"C:\Users\vedan\Downloads\student_habits_performance.csv")#reading csv file
student_habits
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
student_habits.head() #top 5 rows
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
student_habits.shape #rows and columns
# Out:
# (1000, 16)

# %%
student_habits.info() #information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
student_habits.describe() #statical summery of dataset
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
student_habits.isnull().sum() #checking null values
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
student_habits_update_dataset = student_habits.dropna()#deleting rows with null values
student_habits = student_habits_update_dataset
student_habits.to_csv('student_habits_update_dataset.csv', index = False)#saving updated dataset

# %%
student_habits_update_dataset.isnull().sum()#checking null values
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
student_habits_update_dataset.shape #checking rows and columns
# Out:
# (909, 16)

# %%
student_habits_update_dataset.info()#checking information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 909 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     909 non-null    object
#  1   age                            909 non-null    int64
#  2   gender                         909 non-null    object
#  3   study_hours_per_day            909 non-null    float64
#  4   social_media_hours             909 non-null    float64
#  5   netflix_hours                  909 non-null    float64
#  6   part_time_job                  909 non-null    object
#  7   attendance_percentage          909 non-null    float64
#  8   sleep_hours                    909 non-null    float64
#  9   diet_quality                   909 non-null    object
#  10  exercise_frequency             909 non-null    int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
student_habits_update_dataset.describe()#staticle summary about dataset
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# ...

# %%
duplicate = student_habits_update_dataset.drop_duplicates() #checking duplicate values
duplicate
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize']=(12,6)

# %%
numerical_cols =['age','study_hours_per_day','social_media_hours','netflix_hours','attendance_percentage','sleep_hours','exercise_frequency','internet_quality','mental_health_rating','exam_score']
for col in numerical_cols:
    sns.histplot(student_habits_update_dataset[col],kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
categorical_cols = ['gender','part_time_job','parental_education_level','internet_quality','extracurricular_participation']
for col in categorical_cols:
    sns.countplot(x=student_habits_update_dataset[col])
    plt.title(f'count of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(x=student_habits_update_dataset[col], y=student_habits_update_dataset['exam_score'])
    plt.title(f'Exam score by {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
scatter_features =['study_hours_per_day','social_media_hours','sleep_hours']

for col in scatter_features:
    sns.scatterplot(data=student_habits_update_dataset, x=col, y='exam_score', hue='gender')
    plt.title(f'{col} vs Exam Score')
    plt.show()

# %%
for col in student_habits_update_dataset[numerical_cols]:
    if student_habits_update_dataset[col].dtype =='object':
       student_habits_update_dataset[col] = student_habits_update_dataset[col].astype('category').cat.codes
        
corr = student_habits_update_dataset[numerical_cols].corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot = True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
selected_features =['study_hours_per_day','sleep_hours','social_media_hours','mental_health_rating','exam_score']
sns.pairplot(student_habits_update_dataset[selected_features], diag_kind='kde')
plt.show()

# %%
grouped = student_habits_update_dataset.groupby(['parental_education_level','gender'])['exam_score'].mean().reset_index()
sns.barplot(data=grouped, x='parental_education_level', y='exam_score', hue='gender')
plt.title('Mean Exam Score by Parental Education and Gender')
plt.xticks(rotation=45)
plt.show()

# %%
sns.violinplot(data=student_habits_update_dataset, x='diet_quality', y='exam_score')
plt.title('Exam Score by Diet Quality')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

cluster_data = student_habits_update_dataset[numerical_cols].dropna()
scaler = StandardScaler()
scaled = scaler.fit_transform(cluster_data)

kmeans = KMeans(n_clusters=3, random_state=42)
cluster_data['cluster'] = kmeans.fit_predict(scaled)

pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled)
cluster_data['PCA1'] =pca_result[:,0]
cluster_data['PCA2'] =pca_result[:,1]

sns.scatterplot(data=cluster_data, x='PCA1', y='PCA2', hue='cluster', palette='Set2')
plt.title("Cluster of Students (PCA + KMeans)")
plt.show()
